# %%
# run models notebook -- similar to import
# %run models.ipynb

# %%
# training different neural net structures
## baseline model
model, variables = create_vanilla_nn(data,death,"adam",learning_rate=0.1,batch_size=128,layers=[(20,"sigmoid")])
train_model(model,variables,epochs=60)

# %%
# change the number of layers
## two layers
layers =[(20,"sigmoid"),(20,"sigmoid")]
model, variables = create_vanilla_nn(data,death,optimizer_name="adam",learning_rate= 0.1,
                                                batch_size=128,layers = layers)
train_model(model,variables,epochs=60)

## three layers
layers =[(20,"sigmoid"),(20,"sigmoid"),(20,"sigmoid")]
model, variables = create_vanilla_nn(data,death,optimizer_name="adam",learning_rate= 0.1,
                                                batch_size=128,layers = layers)
train_model(model,variables,epochs=60)

## four layers
layers =[(20,"sigmoid"),(20,"sigmoid"),(20,"sigmoid"),(20,"sigmoid")]
model, variables = create_vanilla_nn(data,death,optimizer_name="adam",learning_rate= 0.1,
                                                batch_size=128,layers = layers)
train_model(model,variables,epochs=60)

## five layers
layers =[(20,"sigmoid"),(20,"sigmoid"),(20,"sigmoid"),(20,"sigmoid"),(20,"sigmoid")]
model, variables = create_vanilla_nn(data,death,optimizer_name="adam",learning_rate= 0.1,
                                                batch_size=128,layers = layers)
train_model(model,variables,epochs=60)

# %%
for frac in np.linspace(0,1,num=5):
    end = int(data.shape[0]*frac)
    small_sample_x = data[:end,:]
    small_sample_y = death[:end,:]
    
    model, variables = create_vanilla_nn(small_sample_x,small_sample_y,"adam",learning_rate=0.01,batch_size=128,layers=[(20,"sigmoid")])
    train_model(model,variables,epochs=600)
# Out:
# 813

# %%
layers =[(20,"sigmoid"),(20,"sigmoid")]
model, variables = create_vanilla_nn(data,death,optimizer_name="adam",learning_rate= 0.1,
                                                batch_size=128,layers = layers)
train_model(model,variables,epochs=100)
