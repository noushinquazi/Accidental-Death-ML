# %%
# run models notebook -- similar to import
# %run data_preprocessing.ipynb
# %run models.ipynb

# %%
# training different neural net structures
## baseline model
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=[(50,"sigmoid")])
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

# %%
# change the number of layers
## two layers
layers =[(50,"sigmoid"),(50,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

## three layers
layers =[(50,"sigmoid"),(50,"sigmoid"),(50,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

## four layers
layers =[(50,"sigmoid"),(50,"sigmoid"),(50,"sigmoid"),(50,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

## five layers
layers =[(50,"sigmoid"),(50,"sigmoid"),(50,"sigmoid"),(50,"sigmoid"),(50,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

# %%
# change the width of layers pt.1
## two layers - 100 100
layers =[(100,"sigmoid"),(100,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

## two layers - 100 75
layers =[(20,"sigmoid"),(75,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

## two layers - 100 50
layers =[(100,"sigmoid"),(50,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

## two layers - 100 25
layers =[(100,"sigmoid"),(25,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

# %%
# change the width of layers pt.2
## three layers - 100 100 75
layers =[(100,"sigmoid"),(100,"sigmoid"),(75,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

## three layers - 100 75 50
layers =[(20,"sigmoid"),(10,"sigmoid"),(5,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)

## three layers - 100 50 25
layers =[(15,"sigmoid"),(10,"sigmoid"),(5,"sigmoid")]
model, variables = create_vanilla_nn(num_features,num_labels,"Adam","multi-label",layers=layers)
train_model(training_input,training_output,model,variables, learning_rate = 0.1, epochs = 20)
